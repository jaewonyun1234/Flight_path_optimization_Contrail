# %%
from typing import Protocol
class AircraftPerformance(Protocol):
    def fuel_burn(self, altitude, speed,mass):
        "return fuel burn kg per second given alti"
        ...
        
    def climb_cost(self,mass, fl_from, fl_to):
        ...
        
    def optimal_altitude(self,mass):
        ...
    def aircraft_status(self):
        ...
